# %%
# !pip3 list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# accelerate                               0.26.1
# aiohttp                                  3.9.3
# aiosignal                                1.3.1
# annotated-types                          0.6.0
# anyio                                    4.2.0
# archspec                                 0.2.1
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.7.2
# asttokens                                2.0.5
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# Babel                                    2.14.0
# backcall                                 0.2.0
# backoff                                  2.2.1
# ...
