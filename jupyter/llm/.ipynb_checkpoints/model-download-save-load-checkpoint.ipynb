# %%
import transformers
import getpass
import torch
import os 
from transformers import LlamaForCausalLM, LlamaTokenizer, LlamaTokenizerFast, BitsAndBytesConfig
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoConfig
from peft import PeftModel

# %%
default_path = os.getcwd()
data_path = os.path.join(default_path, '../../data')
model_path = os.path.join(default_path, '../../models')
config_path = os.path.join(default_path, '../../config')

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Download Llama2 Model

# %%
model_id = "kfkas/Llama-2-ko-7b-Chat"

# %%
tokenizer = LlamaTokenizerFast.from_pretrained(model_id)

# %%
tokenizer = LlamaTokenizerFast.from_pretrained(model_id)
model = LlamaForCausalLM.from_pretrained(
    model_id, device_map={"": 0},torch_dtype=torch.float16, low_cpu_mem_usage=True
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
tokenizer.save_pretrained(os.path.join(model_path, 'llama2_origin_tok'))
# Out:
# ('/rag/jupyter/llm/../../models/llama2_origin_tok/tokenizer_config.json',
#  '/rag/jupyter/llm/../../models/llama2_origin_tok/special_tokens_map.json',
#  '/rag/jupyter/llm/../../models/llama2_origin_tok/tokenizer.json')

# %%
len(tokenizer), tokenizer
# Out:
# (46336,
#  LlamaTokenizerFast(name_or_path='kfkas/Llama-2-ko-7b-Chat', vocab_size=46336, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
#  	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	30393: AddedToken("이", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30708: AddedToken("의", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30709: AddedToken("다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30784: AddedToken("스", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30791: AddedToken("사", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30811: AddedToken("지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30826: AddedToken("리", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30827: AddedToken("기", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30852: AddedToken("정", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30860: AddedToken("아", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30877: AddedToken("한", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30889: AddedToken("시", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30890: AddedToken("대", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30903: AddedToken("가", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30906: AddedToken("로", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30918: AddedToken("인", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30944: AddedToken("하", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30970: AddedToken("수", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	30981: AddedToken("주", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31000: AddedToken("동", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31013: AddedToken("자", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31054: AddedToken("에", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31063: AddedToken("니", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31081: AddedToken("는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31093: AddedToken("서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31102: AddedToken("김", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31126: AddedToken("성", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31129: AddedToken("어", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31136: AddedToken("도", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31137: AddedToken("고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31153: AddedToken("일", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31158: AddedToken("상", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31170: AddedToken("전", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31177: AddedToken("트", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31189: AddedToken("소", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31197: AddedToken("라", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31198: AddedToken("원", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31199: AddedToken("보", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31207: AddedToken("나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31225: AddedToken("화", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31231: AddedToken("구", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31262: AddedToken("신", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31279: AddedToken("부", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31285: AddedToken("연", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31286: AddedToken("을", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31288: AddedToken("영", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31293: AddedToken("국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31299: AddedToken("장", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31306: AddedToken("제", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31327: AddedToken("우", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31334: AddedToken("공", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31345: AddedToken("선", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31346: AddedToken("오", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31354: AddedToken("은", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31362: AddedToken("미", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31378: AddedToken("경", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31406: AddedToken("문", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31408: AddedToken("조", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31417: AddedToken("마", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31435: AddedToken("해", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31457: AddedToken("여", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31458: AddedToken("산", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31487: AddedToken("비", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31493: AddedToken("드", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31517: AddedToken("를", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31527: AddedToken("요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31533: AddedToken("유", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31536: AddedToken("진", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31563: AddedToken("천", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31571: AddedToken("년", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31578: AddedToken("세", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31582: AddedToken("민", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31603: AddedToken("호", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31607: AddedToken("그", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31680: AddedToken("현", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31699: AddedToken("군", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31716: AddedToken("무", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31724: AddedToken("위", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31734: AddedToken("안", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31736: AddedToken("박", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31737: AddedToken("용", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31746: AddedToken("단", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31747: AddedToken("면", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31754: AddedToken("남", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31774: AddedToken("강", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31781: AddedToken("씨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31789: AddedToken("개", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31804: AddedToken("들", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31817: AddedToken("차", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31822: AddedToken("학", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31826: AddedToken("만", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31856: AddedToken("터", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31895: AddedToken("식", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31906: AddedToken("과", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31925: AddedToken("타", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31930: AddedToken("종", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31940: AddedToken("내", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31941: AddedToken("중", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31945: AddedToken("방", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31950: AddedToken("월", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31953: AddedToken("회", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31962: AddedToken("모", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31963: AddedToken("바", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31966: AddedToken("음", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31972: AddedToken("교", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31973: AddedToken("재", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31976: AddedToken("명", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31980: AddedToken("합", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31987: AddedToken("역", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31989: AddedToken("백", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	31996: AddedToken("왕", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32000: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32001: AddedToken("▁이", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32002: AddedToken("▁대", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32003: AddedToken("▁사", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32004: AddedToken("▁그", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32005: AddedToken("▁있", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32006: AddedToken("으로", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32007: AddedToken("▁지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32008: AddedToken("▁아", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32009: AddedToken("니다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32010: AddedToken("▁정", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32011: AddedToken("▁하", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32012: AddedToken("에서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32013: AddedToken("▁기", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32014: AddedToken("▁전", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32015: AddedToken("▁가", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32016: AddedToken("▁한", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32017: AddedToken("▁수", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32018: AddedToken("했다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32019: AddedToken("▁나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32020: AddedToken("하고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32021: AddedToken("▁다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32022: AddedToken("하는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32023: AddedToken("▁안", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32024: AddedToken("▁보", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32025: AddedToken("▁국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32026: AddedToken("▁시", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32027: AddedToken("▁자", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32028: AddedToken("▁인", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32029: AddedToken("▁공", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32030: AddedToken("▁중", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32031: AddedToken("▁조", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32032: AddedToken("▁제", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32033: AddedToken("▁것", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32034: AddedToken("▁주", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32035: AddedToken("▁없", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32036: AddedToken("▁일", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32037: AddedToken("▁어", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32038: AddedToken("▁문", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32039: AddedToken("들이", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32040: AddedToken("▁부", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32041: AddedToken("▁잘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32042: AddedToken("▁마", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32043: AddedToken("습니다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32044: AddedToken("이다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32045: AddedToken("▁모", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32046: AddedToken("▁경", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32047: AddedToken("▁말", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32048: AddedToken("는데", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32049: AddedToken("▁해", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32050: AddedToken("▁좋", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32051: AddedToken("▁무", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32052: AddedToken("▁오", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32053: AddedToken("▁우", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32054: AddedToken("▁개", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32055: AddedToken("▁등", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32056: AddedToken("▁위", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32057: AddedToken("▁진", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32058: AddedToken("▁내", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32059: AddedToken("▁신", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32060: AddedToken("▁저", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32061: AddedToken("▁상", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32062: AddedToken("▁만", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32063: AddedToken("라고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32064: AddedToken("▁여", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32065: AddedToken("▁있다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32066: AddedToken("▁선", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32067: AddedToken("▁미", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32068: AddedToken("▁고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32069: AddedToken("▁소", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32070: AddedToken("▁구", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32071: AddedToken("▁더", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32072: AddedToken("▁비", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32073: AddedToken("▁생", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32074: AddedToken("▁유", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32075: AddedToken("네요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32076: AddedToken("▁바", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32077: AddedToken("▁거", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32078: AddedToken("▁세", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32079: AddedToken("한다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32080: AddedToken("들어", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32081: AddedToken("▁국민", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32082: AddedToken("▁많", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32083: AddedToken("▁않", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32084: AddedToken("▁최", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32085: AddedToken("▁받", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32086: AddedToken("▁당", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32087: AddedToken("까지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32088: AddedToken("▁감", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32089: AddedToken("▁서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32090: AddedToken("▁의", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32091: AddedToken("▁김", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32092: AddedToken("▁못", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32093: AddedToken("▁관", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32094: AddedToken("▁방", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32095: AddedToken("▁도", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32096: AddedToken("다고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32097: AddedToken("▁같", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32098: AddedToken("▁배", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32099: AddedToken("지만", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32100: AddedToken("▁사람", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32101: AddedToken("▁발", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32102: AddedToken("▁연", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32103: AddedToken("면서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32104: AddedToken("▁아니", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32105: AddedToken("들은", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32106: AddedToken("▁강", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32107: AddedToken("▁너", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32108: AddedToken("하게", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32109: AddedToken("▁예", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32110: AddedToken("통령", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32111: AddedToken("합니다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32112: AddedToken("아요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32113: AddedToken("▁재", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32114: AddedToken("이라", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32115: AddedToken("해서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32116: AddedToken("▁민", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32117: AddedToken("▁되", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32118: AddedToken("▁알", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32119: AddedToken("▁확", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32120: AddedToken("▁통", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32121: AddedToken("▁남", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32122: AddedToken("세요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32123: AddedToken("▁있는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32124: AddedToken("▁반", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32125: AddedToken("▁윤", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32126: AddedToken("▁불", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32127: AddedToken("▁입", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32128: AddedToken("▁현", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32129: AddedToken("▁영", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32130: AddedToken("▁장", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32131: AddedToken("▁들어", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32132: AddedToken("▁집", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32133: AddedToken("▁원", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32134: AddedToken("▁대통령", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32135: AddedToken("▁동", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32136: AddedToken("에게", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32137: AddedToken("부터", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32138: AddedToken("▁올", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32139: AddedToken("▁중국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32140: AddedToken("▁살", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32141: AddedToken("▁차", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32142: AddedToken("다는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32143: AddedToken("▁또", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32144: AddedToken("이나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32145: AddedToken("▁성", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32146: AddedToken("▁결", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32147: AddedToken("▁후", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32148: AddedToken("▁추", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32149: AddedToken("▁할", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32150: AddedToken("▁분", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32151: AddedToken("▁파", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32152: AddedToken("▁참", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32153: AddedToken("▁왜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32154: AddedToken("▁실", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32155: AddedToken("▁생각", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32156: AddedToken("▁노", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32157: AddedToken("▁대한", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32158: AddedToken("▁검", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32159: AddedToken("▁코", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32160: AddedToken("▁스", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32161: AddedToken("▁문재", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32162: AddedToken("어요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32163: AddedToken("▁계", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32164: AddedToken("▁지난", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32165: AddedToken("▁박", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32166: AddedToken("▁하는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32167: AddedToken("▁때", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32168: AddedToken("▁맞", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32169: AddedToken("으면", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32170: AddedToken("▁교", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32171: AddedToken("▁적", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32172: AddedToken("▁우리", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32173: AddedToken("▁한국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32174: AddedToken("▁따", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32175: AddedToken("하지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32176: AddedToken("▁마음", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32177: AddedToken("▁역", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32178: AddedToken("▁매", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32179: AddedToken("▁니", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32180: AddedToken("▁나라", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32181: AddedToken("보다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32182: AddedToken("▁정말", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32183: AddedToken("▁출", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32184: AddedToken("▁물", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32185: AddedToken("▁쓰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32186: AddedToken("▁뭐", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32187: AddedToken("대로", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32188: AddedToken("▁많이", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32189: AddedToken("하면", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32190: AddedToken("▁건", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32191: AddedToken("▁밝", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32192: AddedToken("리고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32193: AddedToken("▁정부", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32194: AddedToken("하다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32195: AddedToken("▁피", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32196: AddedToken("적으로", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32197: AddedToken("었다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32198: AddedToken("▁특", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32199: AddedToken("▁이런", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32200: AddedToken("▁처", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32201: AddedToken("▁누", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32202: AddedToken("▁두", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32203: AddedToken("적인", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32204: AddedToken("▁청", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32205: AddedToken("▁진짜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32206: AddedToken("▁민주", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32207: AddedToken("▁설", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32208: AddedToken("된다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32209: AddedToken("▁포", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32210: AddedToken("는거", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32211: AddedToken("▁열", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32212: AddedToken("▁단", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32213: AddedToken("로나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32214: AddedToken("입니다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32215: AddedToken("해야", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32216: AddedToken("▁달", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32217: AddedToken("이라고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32218: AddedToken("▁너무", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32219: AddedToken("▁앞", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32220: AddedToken("▁지금", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32221: AddedToken("에는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32222: AddedToken("니까", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32223: AddedToken("▁마음에", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32224: AddedToken("▁문재인", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32225: AddedToken("렇게", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32226: AddedToken("았습니다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32227: AddedToken("▁법", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32228: AddedToken("들의", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32229: AddedToken("▁투", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32230: AddedToken("▁금", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32231: AddedToken("▁죽", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32232: AddedToken("▁좀", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32233: AddedToken("▁행", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32234: AddedToken("▁과", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32235: AddedToken("▁화", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32236: AddedToken("▁애", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32237: AddedToken("인데", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32238: AddedToken("▁본", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32239: AddedToken("▁양", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32240: AddedToken("▁외", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32241: AddedToken("하기", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32242: AddedToken("▁요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32243: AddedToken("▁했", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32244: AddedToken("이고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32245: AddedToken("겠다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32246: AddedToken("▁운", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32247: AddedToken("▁들어요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32248: AddedToken("▁위해", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32249: AddedToken("▁좋아요", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32250: AddedToken("▁넘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32251: AddedToken("▁정치", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32252: AddedToken("▁북", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32253: AddedToken("▁언", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32254: AddedToken("▁심", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32255: AddedToken("▁서울", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32256: AddedToken("▁빠", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32257: AddedToken("리는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32258: AddedToken("나라", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32259: AddedToken("▁치", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32260: AddedToken("▁문제", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32261: AddedToken("▁그냥", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32262: AddedToken("▁함", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32263: AddedToken("▁이번", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32264: AddedToken("▁미국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32265: AddedToken("▁돈", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32266: AddedToken("▁판", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32267: AddedToken("▁코로나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32268: AddedToken("천지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32269: AddedToken("▁평", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32270: AddedToken("▁회", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32271: AddedToken("▁새", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32272: AddedToken("▁총", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32273: AddedToken("▁작", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32274: AddedToken("▁민주당", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32275: AddedToken("▁백", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32276: AddedToken("▁임", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32277: AddedToken("▁밝혔", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32278: AddedToken("▁직", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32279: AddedToken("▁돌", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32280: AddedToken("▁같은", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32281: AddedToken("▁하고", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32282: AddedToken("▁손", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32283: AddedToken("▁가격", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32284: AddedToken("▁배송", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32285: AddedToken("됐다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32286: AddedToken("▁명", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32287: AddedToken("▁걸", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32288: AddedToken("▁증", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32289: AddedToken("▁드", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32290: AddedToken("▁간", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32291: AddedToken("▁종", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32292: AddedToken("▁완", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32293: AddedToken("자가", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32294: AddedToken("▁지원", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32295: AddedToken("라는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32296: AddedToken("▁이제", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32297: AddedToken("▁힘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32298: AddedToken("▁통해", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32299: AddedToken("▁빨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32300: AddedToken("▁얼", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32301: AddedToken("▁것으로", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32302: AddedToken("▁필", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32303: AddedToken("▁한다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32304: AddedToken("자는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32305: AddedToken("▁했다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32306: AddedToken("에도", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32307: AddedToken("▁그러", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32308: AddedToken("들을", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32309: AddedToken("▁이상", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32310: AddedToken("석열", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32311: AddedToken("▁밝혔다", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32312: AddedToken("되는", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32313: AddedToken("▁이어", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32314: AddedToken("기를", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32315: AddedToken("해라", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32316: AddedToken("▁활", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32317: AddedToken("▁프", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32318: AddedToken("▁일본", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32319: AddedToken("▁하나", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32320: AddedToken("어서", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32321: AddedToken("▁초", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32322: AddedToken("시아", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32323: AddedToken("▁근", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32324: AddedToken("▁그래", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32325: AddedToken("▁산", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32326: AddedToken("이지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32327: AddedToken("민국", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32328: AddedToken("▁검찰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32329: AddedToken("▁아닌", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32330: AddedToken("▁지지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32331: AddedToken("▁신천지", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32332: AddedToken("▁사용", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32333: AddedToken("▁인간", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	32334: AddedToken("▁속", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# ...
#  	46184: AddedToken("썅", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46185: AddedToken("딕", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46186: AddedToken("퀀", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46187: AddedToken("딤", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46188: AddedToken("궂", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46189: AddedToken("킁", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46190: AddedToken("듦", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46191: AddedToken("썹", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46192: AddedToken("펩", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46193: AddedToken("뀜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46194: AddedToken("곶", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46195: AddedToken("룻", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46196: AddedToken("얕", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46197: AddedToken("밈", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46198: AddedToken("궜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46199: AddedToken("콥", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46200: AddedToken("쳣", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46201: AddedToken("싯", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46202: AddedToken("뼛", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46203: AddedToken("슘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46204: AddedToken("겡", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46205: AddedToken("잰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46206: AddedToken("웜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46207: AddedToken("괸", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46208: AddedToken("뎃", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46209: AddedToken("빴", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46210: AddedToken("짊", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46211: AddedToken("좇", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46212: AddedToken("갉", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46213: AddedToken("뒹", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46214: AddedToken("숴", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46215: AddedToken("얏", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46216: AddedToken("퇘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46217: AddedToken("뻤", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46218: AddedToken("텁", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46219: AddedToken("셴", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46220: AddedToken("앴", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46221: AddedToken("덟", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46222: AddedToken("섣", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46223: AddedToken("뎀", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46224: AddedToken("뉜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46225: AddedToken("텼", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46226: AddedToken("숱", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46227: AddedToken("깠", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46228: AddedToken("잿", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46229: AddedToken("콱", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46230: AddedToken("튈", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46231: AddedToken("띈", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46232: AddedToken("쭵", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46233: AddedToken("켯", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46234: AddedToken("깻", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46235: AddedToken("꺠", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46236: AddedToken("뗀", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46237: AddedToken("촐", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46238: AddedToken("낑", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46239: AddedToken("큘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46240: AddedToken("닼", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46241: AddedToken("찹", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46242: AddedToken("뇽", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46243: AddedToken("낵", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46244: AddedToken("넝", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46245: AddedToken("씰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46246: AddedToken("갰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46247: AddedToken("됌", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46248: AddedToken("땄", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46249: AddedToken("뾰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46250: AddedToken("찻", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46251: AddedToken("쨍", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46252: AddedToken("낍", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46253: AddedToken("냇", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46254: AddedToken("퉈", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46255: AddedToken("읊", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46256: AddedToken("탤", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46257: AddedToken("몄", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46258: AddedToken("뮨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46259: AddedToken("헹", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46260: AddedToken("쫘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46261: AddedToken("얜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46262: AddedToken("룽", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46263: AddedToken("숄", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46264: AddedToken("뮐", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46265: AddedToken("뿅", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46266: AddedToken("얗", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46267: AddedToken("쨉", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46268: AddedToken("졷", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46269: AddedToken("헥", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46270: AddedToken("긔", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46271: AddedToken("뎁", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46272: AddedToken("젔", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46273: AddedToken("꼐", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46274: AddedToken("벵", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46275: AddedToken("셍", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46276: AddedToken("팻", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46277: AddedToken("눅", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46278: AddedToken("놧", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46279: AddedToken("렙", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46280: AddedToken("넙", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46281: AddedToken("츰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46282: AddedToken("횃", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46283: AddedToken("맣", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46284: AddedToken("앖", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46285: AddedToken("삘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46286: AddedToken("튄", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46287: AddedToken("먄", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46288: AddedToken("펭", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46289: AddedToken("띔", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46290: AddedToken("솨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46291: AddedToken("튭", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46292: AddedToken("갬", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46293: AddedToken("냨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46294: AddedToken("뷸", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46295: AddedToken("괭", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46296: AddedToken("툽", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46297: AddedToken("왁", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46298: AddedToken("켐", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46299: AddedToken("깼", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46300: AddedToken("힝", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46301: AddedToken("꼿", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46302: AddedToken("웟", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46303: AddedToken("췬", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46304: AddedToken("슙", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46305: AddedToken("솎", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46306: AddedToken("읏", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46307: AddedToken("쌰", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46308: AddedToken("쟌", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46309: AddedToken("옅", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46310: AddedToken("샊", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46311: AddedToken("젬", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46312: AddedToken("쑨", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46313: AddedToken("춧", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46314: AddedToken("켠", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46315: AddedToken("겆", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46316: AddedToken("읎", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46317: AddedToken("쥑", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46318: AddedToken("샠", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46319: AddedToken("갛", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46320: AddedToken("죵", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46321: AddedToken("땔", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46322: AddedToken("꽥", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46323: AddedToken("짘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46324: AddedToken("앜", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46325: AddedToken("쯪", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46326: AddedToken("퓸", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46327: AddedToken("앎", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46328: AddedToken("챘", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46329: AddedToken("컹", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46330: AddedToken("묽", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46331: AddedToken("<|sep|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46332: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46333: AddedToken("<|acc|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46334: AddedToken("<|rrn|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  	46335: AddedToken("<|tel|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
#  })

# %% [markdown]
# ### Save Llama2 Model

# %% [raw]
# torch.save(model, os.path.join(model_path, 'llama2.pth'))

# %%
model.save_pretrained(save_directory=os.path.join(model_path, "llama2_origin"))

# %% [markdown]
# ### Load Llama2 Model

# %%
model_dir = os.path.join(model_path, 'llama2_origin')

# %%
model = LlamaForCausalLM.from_pretrained(model_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
AutoTokenizer = AutoTokenizer.from_pretrained(os.path.join(model_dir, 'tokenizer'))

# %%
# AutoTokenizer = AutoTokenizer.from_pretrained(os.path.join(model_dir, 'tokenizer'))
LlamaTokenizer = LlamaTokenizerFast.from_pretrained(os.path.join(model_dir, 'tokenizer'))   # LlamaTokenizer (x)  -> LlamaTokenizerFast (o)

# %%
len(AutoTokenizer.vocab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(AutoTokenizer.vocab)
#
# AttributeError: type object 'AutoTokenizer' has no attribute 'vocab'

# %% [markdown]
# ### Download Mistral Model

# %%
model_name='davidkim205/komt-mistral-7b-v1'
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, low_cpu_mem_usage=True) # , device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
tokenizer

# %%
tokenizer.vocab

# %% [markdown]
# ### Save Mistral Model

# %%
model.save_pretrained(save_directory=os.path.join(model_path, "mistral_origin"))

# %%
tokenizer.save_pretrained(os.path.join(model_path, 'mistral_origin', 'tokenizer'))

# %% [markdown]
# ### Load Mistral Model

# %%
model_dir = os.path.join(model_path, "mistral_origin")

# %%
tokenizer = AutoTokenizer.from_pretrained(os.path.join(model_dir, 'tokenizer'))

# %% [raw]
# tokenizer = LlamaTokenizerFast.from_pretrained(os.path.join(model_dir, 'tokenizer'))   # LlamaTokenizer (x)  -> LlamaTokenizerFast (o)

# %%
model = AutoModelForCausalLM.from_pretrained(model_dir, torch_dtype=torch.float16, low_cpu_mem_usage=True) # , device_map="auto")

# %%
model
